# %% [markdown]
# Импорт

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Данные: объекты на местности

# %%
df = pd.read_csv('../data/case1data.csv')
plt.scatter(df['x'], df['y'], s=3)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=0, n_init="auto").fit(df)

# %%
centers = np.transpose(kmeans.cluster_centers_)
plt.scatter(centers[0], centers[1], s=s)

# %%
s = [sum(kmeans.labels_ == i)*10 for i in range(len(kmeans.cluster_centers_))]
plt.scatter(centers[0], centers[1], s=s)
